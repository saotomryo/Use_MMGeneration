# %% [markdown]
# <a href="https://colab.research.google.com/github/saotomryo/Use_MMGeneration/blob/main/Use_MMGeneration_Train_CycleGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import cv2
from glob import glob
print(torch.__version__)
device = "cuda" if torch.cuda.is_available() else "cpu"
print("device = ", device)

# %% [markdown]
# ## 環境準備 MMCV MMGenerationのインストール

# %%
# MMCVのインストール
# !pip install -U openmim
# !mim install mmcv-full

# %%
# !git clone https://github.com/open-mmlab/mmgeneration.git
# %cd /content/mmgeneration
# !pip install -v -e .  # or "python setup.py develop"

# %% [markdown]
# # コンフィグファイルの編集
#
# CycleGANでは、変換を行いたい2種類の画像を使って学習を行うことになりますが、コンフィグファイルを確認しても、2種類の画像のフォルダパスを直接指定することは出来なさそうでした。
# 取りあえずは、サンプルのテストデータと同じフォルダ構成にする必要がありそうです。
#
# 画像のルートフォルダ
# |
# |  -  trainA  （グループAの学習用の画像フォルダ）
# |
# |  -  trainB　（グループBの学習用の画像フォルダ）
# |
# |  -  testA　 （グループAのテスト用の画像フォルダ）
# |
# |  -  testB　 （グループBのテスト用の画像フォルダ）

# %%
from mmcv import Config
cfg = Config.fromfile('./configs/cyclegan/cyclegan_lsgan_id0_resnet_in_facades_b1x1_80k.py')

# %%
# データのパス
cfg.data.train.dataroot = # 画像のルートフォルダ
cfg.data.test.dataroot = # 画像のルートフォルダ
cfg.data.val.dataroot = # 画像のルートフォルダ
cfg.gpu_ids = range(0, 1)
cfg.seed = 123


print(f'Config:\n{cfg.pretty_text}')

# %% [markdown]
# # 学習の実施

# %%
import argparse
import copy
import multiprocessing as mp
import os
import os.path as osp
import platform
import time
import warnings

import cv2
import mmcv
import torch
from mmcv import Config, DictAction
from mmcv.runner import get_dist_info, init_dist
from mmcv.utils import get_git_hash

from mmgen import __version__
from mmgen.apis import set_random_seed, train_model
from mmgen.datasets import build_dataset
from mmgen.models import build_model
from mmgen.utils import collect_env, get_root_logger

# %%
model = build_model(
    cfg.model, train_cfg=cfg.train_cfg, test_cfg=cfg.test_cfg)

datasets = [build_dataset(cfg.data.train)]

timestamp = time.strftime('%Y%m%d_%H%M%S', time.localtime())

meta = dict()
# log env info
env_info_dict = collect_env()
env_info = '\n'.join([(f'{k}: {v}') for k, v in env_info_dict.items()])
dash_line = '-' * 60 + '\n'

meta['env_info'] = env_info
meta['config'] = cfg.pretty_text

train_model(
    model,
    datasets,
    cfg,
    distributed=False,
    timestamp=timestamp,
    meta=meta)
# Out:
# /usr/local/lib/python3.7/dist-packages/mmcv/cnn/bricks/conv_module.py:154: UserWarning: Unnecessary conv bias before batch/instance norm
#   'Unnecessary conv bias before batch/instance norm')
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 2022-07-25 08:26:50,685 - mmgen - INFO - Start running, host: root@9d67c8fab200, work_dir: /content/mmgeneration/work_dirs/experiments/cyclegan_facades_id0
# 2022-07-25 08:26:50,687 - mmgen - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) LinearLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) LinearLrUpdaterHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) LinearLrUpdaterHook
# (LOW         ) IterTimerHook
#  --------------------
# after_train_iter:
# (NORMAL      ) CheckpointHook
# (NORMAL      ) VisualizationHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_epoch:
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# 2022-07-25 08:26:50,692 - mmgen - INFO - workflow: [('train', 1)], max: 80000 iters
# 2022-07-25 08:26:50,696 - mmgen - INFO - Checkpoints will be saved to ./work_dirs/experiments/cyclegan_facades_id0/ckpt/cyclegan_facades_id0 by HardDiskBackend.
# 2022-07-25 08:27:18,795 - mmgen - INFO - Iter [100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 6:12:15, time: 0.280, data_time: 0.007, memory: 2631, loss_gan_d_mask: 0.8035, loss_gan_d_photo: 0.8652, loss_gan_g_mask: 0.8058, loss_gan_g_photo: 0.8570, cycle_loss: 7.6548, loss: 9.3176
# 2022-07-25 08:27:46,236 - mmgen - INFO - Iter [200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 6:08:22, time: 0.274, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.3191, loss_gan_d_photo: 0.3368, loss_gan_g_mask: 0.3326, loss_gan_g_photo: 0.3711, cycle_loss: 6.3926, loss: 7.0964
# 2022-07-25 08:28:13,683 - mmgen - INFO - Iter [300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 6:06:48, time: 0.274, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2949, loss_gan_d_photo: 0.2804, loss_gan_g_mask: 0.3809, loss_gan_g_photo: 0.3299, cycle_loss: 6.2418, loss: 6.9526
# 2022-07-25 08:28:41,119 - mmgen - INFO - Iter [400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 6:05:45, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2770, loss_gan_d_photo: 0.2940, loss_gan_g_mask: 0.3659, loss_gan_g_photo: 0.3608, cycle_loss: 5.9937, loss: 6.7204
# 2022-07-25 08:29:08,561 - mmgen - INFO - Iter [500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 6:04:57, time: 0.274, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2766, loss_gan_d_photo: 0.2650, loss_gan_g_mask: 0.3754, loss_gan_g_photo: 0.3605, cycle_loss: 5.7886, loss: 6.5245
# 2022-07-25 08:29:35,980 - mmgen - INFO - Iter [600/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 6:04:13, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2624, loss_gan_d_photo: 0.2715, loss_gan_g_mask: 0.3949, loss_gan_g_photo: 0.3744, cycle_loss: 5.8118, loss: 6.5811
# 2022-07-25 08:30:03,417 - mmgen - INFO - Iter [700/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 6:03:35, time: 0.274, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2449, loss_gan_d_photo: 0.2614, loss_gan_g_mask: 0.3846, loss_gan_g_photo: 0.3826, cycle_loss: 5.7936, loss: 6.5609
# 2022-07-25 08:30:30,852 - mmgen - INFO - Iter [800/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 6:03:00, time: 0.274, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2614, loss_gan_d_photo: 0.2530, loss_gan_g_mask: 0.4165, loss_gan_g_photo: 0.3992, cycle_loss: 5.5659, loss: 6.3816
# 2022-07-25 08:30:58,298 - mmgen - INFO - Iter [900/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 6:02:28, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2457, loss_gan_d_photo: 0.2560, loss_gan_g_mask: 0.4179, loss_gan_g_photo: 0.4092, cycle_loss: 5.0939, loss: 5.9211
# 2022-07-25 08:31:25,718 - mmgen - INFO - Iter [1000/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 6:01:54, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2512, loss_gan_d_photo: 0.2727, loss_gan_g_mask: 0.4079, loss_gan_g_photo: 0.4149, cycle_loss: 5.4199, loss: 6.2427
# 2022-07-25 08:31:53,146 - mmgen - INFO - Iter [1100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 6:01:23, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2316, loss_gan_d_photo: 0.2440, loss_gan_g_mask: 0.4570, loss_gan_g_photo: 0.4203, cycle_loss: 5.3336, loss: 6.2108
# 2022-07-25 08:32:20,582 - mmgen - INFO - Iter [1200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 6:00:52, time: 0.274, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2330, loss_gan_d_photo: 0.2431, loss_gan_g_mask: 0.4417, loss_gan_g_photo: 0.3649, cycle_loss: 5.4286, loss: 6.2353
# 2022-07-25 08:32:48,018 - mmgen - INFO - Iter [1300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 6:00:22, time: 0.274, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2318, loss_gan_d_photo: 0.2623, loss_gan_g_mask: 0.4488, loss_gan_g_photo: 0.4242, cycle_loss: 5.2187, loss: 6.0918
# 2022-07-25 08:33:15,427 - mmgen - INFO - Iter [1400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:59:51, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2463, loss_gan_d_photo: 0.2511, loss_gan_g_mask: 0.4437, loss_gan_g_photo: 0.4234, cycle_loss: 5.5612, loss: 6.4284
# 2022-07-25 08:33:42,845 - mmgen - INFO - Iter [1500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:59:21, time: 0.274, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2251, loss_gan_d_photo: 0.2318, loss_gan_g_mask: 0.5079, loss_gan_g_photo: 0.4405, cycle_loss: 5.8332, loss: 6.7815
# 2022-07-25 08:34:10,270 - mmgen - INFO - Iter [1600/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:58:51, time: 0.274, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2081, loss_gan_d_photo: 0.2399, loss_gan_g_mask: 0.4941, loss_gan_g_photo: 0.4327, cycle_loss: 5.4999, loss: 6.4267
# 2022-07-25 08:34:37,705 - mmgen - INFO - Iter [1700/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:58:22, time: 0.274, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2437, loss_gan_d_photo: 0.2375, loss_gan_g_mask: 0.3947, loss_gan_g_photo: 0.4016, cycle_loss: 5.5335, loss: 6.3298
# 2022-07-25 08:35:05,153 - mmgen - INFO - Iter [1800/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:57:54, time: 0.274, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2279, loss_gan_d_photo: 0.2388, loss_gan_g_mask: 0.4595, loss_gan_g_photo: 0.4207, cycle_loss: 5.3941, loss: 6.2743
# 2022-07-25 08:35:32,607 - mmgen - INFO - Iter [1900/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:57:26, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2139, loss_gan_d_photo: 0.2365, loss_gan_g_mask: 0.4427, loss_gan_g_photo: 0.4409, cycle_loss: 5.2590, loss: 6.1426
# 2022-07-25 08:36:00,083 - mmgen - INFO - Iter [2000/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:57:00, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2222, loss_gan_d_photo: 0.2514, loss_gan_g_mask: 0.4305, loss_gan_g_photo: 0.4661, cycle_loss: 5.5928, loss: 6.4894
# 2022-07-25 08:36:27,492 - mmgen - INFO - Iter [2100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:56:30, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2278, loss_gan_d_photo: 0.2332, loss_gan_g_mask: 0.4228, loss_gan_g_photo: 0.4475, cycle_loss: 5.2447, loss: 6.1150
# 2022-07-25 08:36:54,956 - mmgen - INFO - Iter [2200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:56:03, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2299, loss_gan_d_photo: 0.2252, loss_gan_g_mask: 0.4358, loss_gan_g_photo: 0.4462, cycle_loss: 4.8616, loss: 5.7437
# 2022-07-25 08:37:22,416 - mmgen - INFO - Iter [2300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:55:35, time: 0.275, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2407, loss_gan_d_photo: 0.2266, loss_gan_g_mask: 0.4405, loss_gan_g_photo: 0.4702, cycle_loss: 5.1114, loss: 6.0220
# 2022-07-25 08:37:49,838 - mmgen - INFO - Iter [2400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:55:07, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2309, loss_gan_d_photo: 0.2181, loss_gan_g_mask: 0.4399, loss_gan_g_photo: 0.4810, cycle_loss: 5.3278, loss: 6.2487
# 2022-07-25 08:38:17,283 - mmgen - INFO - Iter [2500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:54:39, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2226, loss_gan_d_photo: 0.2280, loss_gan_g_mask: 0.4205, loss_gan_g_photo: 0.4322, cycle_loss: 5.0038, loss: 5.8564
# 2022-07-25 08:38:44,737 - mmgen - INFO - Iter [2600/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:54:11, time: 0.275, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2527, loss_gan_d_photo: 0.2178, loss_gan_g_mask: 0.4501, loss_gan_g_photo: 0.4696, cycle_loss: 4.8767, loss: 5.7964
# 2022-07-25 08:39:12,171 - mmgen - INFO - Iter [2700/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:53:43, time: 0.274, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2245, loss_gan_d_photo: 0.2306, loss_gan_g_mask: 0.4226, loss_gan_g_photo: 0.4410, cycle_loss: 4.7758, loss: 5.6395
# 2022-07-25 08:39:39,627 - mmgen - INFO - Iter [2800/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:53:16, time: 0.275, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2143, loss_gan_d_photo: 0.2381, loss_gan_g_mask: 0.4639, loss_gan_g_photo: 0.4619, cycle_loss: 5.2463, loss: 6.1720
# 2022-07-25 08:40:07,032 - mmgen - INFO - Iter [2900/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:52:47, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2383, loss_gan_d_photo: 0.2351, loss_gan_g_mask: 0.4199, loss_gan_g_photo: 0.4469, cycle_loss: 4.8774, loss: 5.7442
# 2022-07-25 08:40:34,491 - mmgen - INFO - Iter [3000/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:52:19, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2396, loss_gan_d_photo: 0.2129, loss_gan_g_mask: 0.4461, loss_gan_g_photo: 0.4810, cycle_loss: 5.3134, loss: 6.2405
# 2022-07-25 08:41:01,915 - mmgen - INFO - Iter [3100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:51:51, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2254, loss_gan_d_photo: 0.2187, loss_gan_g_mask: 0.4807, loss_gan_g_photo: 0.4589, cycle_loss: 5.1485, loss: 6.0880
# 2022-07-25 08:41:29,334 - mmgen - INFO - Iter [3200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:51:23, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2321, loss_gan_d_photo: 0.2286, loss_gan_g_mask: 0.4306, loss_gan_g_photo: 0.4465, cycle_loss: 4.8208, loss: 5.6979
# 2022-07-25 08:41:56,783 - mmgen - INFO - Iter [3300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:50:55, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2196, loss_gan_d_photo: 0.2196, loss_gan_g_mask: 0.4251, loss_gan_g_photo: 0.3925, cycle_loss: 4.7206, loss: 5.5383
# 2022-07-25 08:42:24,268 - mmgen - INFO - Iter [3400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:50:29, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2392, loss_gan_d_photo: 0.2213, loss_gan_g_mask: 0.4128, loss_gan_g_photo: 0.4196, cycle_loss: 4.8328, loss: 5.6652
# 2022-07-25 08:42:51,764 - mmgen - INFO - Iter [3500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:50:02, time: 0.275, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2291, loss_gan_d_photo: 0.2298, loss_gan_g_mask: 0.4135, loss_gan_g_photo: 0.4324, cycle_loss: 4.7096, loss: 5.5555
# 2022-07-25 08:43:19,207 - mmgen - INFO - Iter [3600/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:49:34, time: 0.274, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2424, loss_gan_d_photo: 0.2256, loss_gan_g_mask: 0.3801, loss_gan_g_photo: 0.4496, cycle_loss: 4.5104, loss: 5.3401
# 2022-07-25 08:43:46,631 - mmgen - INFO - Iter [3700/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:49:06, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2347, loss_gan_d_photo: 0.2145, loss_gan_g_mask: 0.4467, loss_gan_g_photo: 0.4019, cycle_loss: 4.6734, loss: 5.5220
# 2022-07-25 08:44:14,074 - mmgen - INFO - Iter [3800/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:48:39, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2323, loss_gan_d_photo: 0.2259, loss_gan_g_mask: 0.4059, loss_gan_g_photo: 0.4494, cycle_loss: 4.6947, loss: 5.5500
# 2022-07-25 08:44:41,511 - mmgen - INFO - Iter [3900/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:48:11, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2339, loss_gan_d_photo: 0.2264, loss_gan_g_mask: 0.4485, loss_gan_g_photo: 0.4404, cycle_loss: 4.8521, loss: 5.7410
# 2022-07-25 08:45:08,960 - mmgen - INFO - Iter [4000/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:47:43, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2221, loss_gan_d_photo: 0.2197, loss_gan_g_mask: 0.4295, loss_gan_g_photo: 0.4153, cycle_loss: 4.7825, loss: 5.6273
# 2022-07-25 08:45:36,455 - mmgen - INFO - Iter [4100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:47:17, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2176, loss_gan_d_photo: 0.2357, loss_gan_g_mask: 0.3970, loss_gan_g_photo: 0.4376, cycle_loss: 4.5640, loss: 5.3986
# 2022-07-25 08:46:03,914 - mmgen - INFO - Iter [4200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:46:49, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2448, loss_gan_d_photo: 0.2236, loss_gan_g_mask: 0.4308, loss_gan_g_photo: 0.3941, cycle_loss: 4.7089, loss: 5.5337
# 2022-07-25 08:46:31,356 - mmgen - INFO - Iter [4300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:46:22, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2148, loss_gan_d_photo: 0.2353, loss_gan_g_mask: 0.4320, loss_gan_g_photo: 0.4188, cycle_loss: 4.8354, loss: 5.6862
# 2022-07-25 08:46:58,818 - mmgen - INFO - Iter [4400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:45:54, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2269, loss_gan_d_photo: 0.2161, loss_gan_g_mask: 0.4225, loss_gan_g_photo: 0.4211, cycle_loss: 4.8103, loss: 5.6539
# 2022-07-25 08:47:26,298 - mmgen - INFO - Iter [4500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:45:27, time: 0.275, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2235, loss_gan_d_photo: 0.2232, loss_gan_g_mask: 0.4164, loss_gan_g_photo: 0.4493, cycle_loss: 4.6545, loss: 5.5202
# 2022-07-25 08:47:53,702 - mmgen - INFO - Iter [4600/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:44:59, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2358, loss_gan_d_photo: 0.2478, loss_gan_g_mask: 0.3903, loss_gan_g_photo: 0.4149, cycle_loss: 4.5136, loss: 5.3188
# 2022-07-25 08:48:21,221 - mmgen - INFO - Iter [4700/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:44:33, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2252, loss_gan_d_photo: 0.2214, loss_gan_g_mask: 0.3960, loss_gan_g_photo: 0.4098, cycle_loss: 4.7424, loss: 5.5482
# 2022-07-25 08:48:48,676 - mmgen - INFO - Iter [4800/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:44:05, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2247, loss_gan_d_photo: 0.2277, loss_gan_g_mask: 0.4141, loss_gan_g_photo: 0.4232, cycle_loss: 4.6024, loss: 5.4398
# 2022-07-25 08:49:16,147 - mmgen - INFO - Iter [4900/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:43:38, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2245, loss_gan_d_photo: 0.2236, loss_gan_g_mask: 0.4544, loss_gan_g_photo: 0.4308, cycle_loss: 4.5980, loss: 5.4831
# 2022-07-25 08:49:43,720 - mmgen - INFO - Iter [5000/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:43:12, time: 0.276, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2276, loss_gan_d_photo: 0.2336, loss_gan_g_mask: 0.3993, loss_gan_g_photo: 0.4340, cycle_loss: 4.6296, loss: 5.4629
# 2022-07-25 08:50:11,144 - mmgen - INFO - Iter [5100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:42:44, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2326, loss_gan_d_photo: 0.2298, loss_gan_g_mask: 0.3993, loss_gan_g_photo: 0.3996, cycle_loss: 4.5562, loss: 5.3552
# 2022-07-25 08:50:38,627 - mmgen - INFO - Iter [5200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:42:17, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2280, loss_gan_d_photo: 0.2288, loss_gan_g_mask: 0.4159, loss_gan_g_photo: 0.4153, cycle_loss: 4.2249, loss: 5.0562
# 2022-07-25 08:51:06,100 - mmgen - INFO - Iter [5300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:41:50, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2221, loss_gan_d_photo: 0.2372, loss_gan_g_mask: 0.3926, loss_gan_g_photo: 0.4268, cycle_loss: 4.2437, loss: 5.0631
# 2022-07-25 08:51:33,556 - mmgen - INFO - Iter [5400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:41:23, time: 0.275, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2484, loss_gan_d_photo: 0.2334, loss_gan_g_mask: 0.3903, loss_gan_g_photo: 0.4276, cycle_loss: 4.3015, loss: 5.1194
# 2022-07-25 08:52:01,026 - mmgen - INFO - Iter [5500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:40:55, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2369, loss_gan_d_photo: 0.2335, loss_gan_g_mask: 0.4153, loss_gan_g_photo: 0.4327, cycle_loss: 4.3966, loss: 5.2447
# 2022-07-25 08:52:28,491 - mmgen - INFO - Iter [5600/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:40:28, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2368, loss_gan_d_photo: 0.2289, loss_gan_g_mask: 0.4032, loss_gan_g_photo: 0.3918, cycle_loss: 4.1452, loss: 4.9402
# 2022-07-25 08:52:55,972 - mmgen - INFO - Iter [5700/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:40:01, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2256, loss_gan_d_photo: 0.2237, loss_gan_g_mask: 0.4071, loss_gan_g_photo: 0.4350, cycle_loss: 4.0009, loss: 4.8430
# 2022-07-25 08:53:23,413 - mmgen - INFO - Iter [5800/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:39:33, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2455, loss_gan_d_photo: 0.2342, loss_gan_g_mask: 0.3871, loss_gan_g_photo: 0.4033, cycle_loss: 4.1892, loss: 4.9796
# 2022-07-25 08:53:50,856 - mmgen - INFO - Iter [5900/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:39:05, time: 0.274, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2256, loss_gan_d_photo: 0.2338, loss_gan_g_mask: 0.3859, loss_gan_g_photo: 0.4073, cycle_loss: 3.9298, loss: 4.7230
# 2022-07-25 08:54:18,339 - mmgen - INFO - Iter [6000/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:38:38, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2264, loss_gan_d_photo: 0.2277, loss_gan_g_mask: 0.4228, loss_gan_g_photo: 0.4428, cycle_loss: 4.1880, loss: 5.0536
# 2022-07-25 08:54:45,818 - mmgen - INFO - Iter [6100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:38:11, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2457, loss_gan_d_photo: 0.2272, loss_gan_g_mask: 0.4269, loss_gan_g_photo: 0.3967, cycle_loss: 4.0730, loss: 4.8967
# 2022-07-25 08:55:13,261 - mmgen - INFO - Iter [6200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:37:43, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2269, loss_gan_d_photo: 0.2274, loss_gan_g_mask: 0.4054, loss_gan_g_photo: 0.4610, cycle_loss: 4.3355, loss: 5.2019
# 2022-07-25 08:55:40,749 - mmgen - INFO - Iter [6300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:37:16, time: 0.275, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2302, loss_gan_d_photo: 0.2339, loss_gan_g_mask: 0.3751, loss_gan_g_photo: 0.4268, cycle_loss: 4.1499, loss: 4.9518
# 2022-07-25 08:56:08,221 - mmgen - INFO - Iter [6400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:36:49, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2395, loss_gan_d_photo: 0.2196, loss_gan_g_mask: 0.4020, loss_gan_g_photo: 0.4090, cycle_loss: 4.1358, loss: 4.9468
# 2022-07-25 08:56:35,651 - mmgen - INFO - Iter [6500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:36:21, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2349, loss_gan_d_photo: 0.2317, loss_gan_g_mask: 0.3278, loss_gan_g_photo: 0.3940, cycle_loss: 3.9921, loss: 4.7139
# 2022-07-25 08:57:03,146 - mmgen - INFO - Iter [6600/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:35:54, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2423, loss_gan_d_photo: 0.2310, loss_gan_g_mask: 0.4300, loss_gan_g_photo: 0.3882, cycle_loss: 4.3346, loss: 5.1528
# 2022-07-25 08:57:30,617 - mmgen - INFO - Iter [6700/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:35:27, time: 0.275, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2249, loss_gan_d_photo: 0.2299, loss_gan_g_mask: 0.3955, loss_gan_g_photo: 0.3595, cycle_loss: 4.1011, loss: 4.8561
# 2022-07-25 08:57:58,128 - mmgen - INFO - Iter [6800/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:35:00, time: 0.275, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2284, loss_gan_d_photo: 0.2347, loss_gan_g_mask: 0.3740, loss_gan_g_photo: 0.3944, cycle_loss: 3.7068, loss: 4.4753
# 2022-07-25 08:58:25,589 - mmgen - INFO - Iter [6900/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:34:32, time: 0.275, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2264, loss_gan_d_photo: 0.2513, loss_gan_g_mask: 0.4127, loss_gan_g_photo: 0.4403, cycle_loss: 4.2467, loss: 5.0997
# 2022-07-25 08:58:55,345 - mmgen - INFO - Iter [7000/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:34:29, time: 0.298, data_time: 0.026, memory: 2631, loss_gan_d_mask: 0.2365, loss_gan_d_photo: 0.2258, loss_gan_g_mask: 0.3989, loss_gan_g_photo: 0.4064, cycle_loss: 4.2070, loss: 5.0123
# 2022-07-25 08:59:22,848 - mmgen - INFO - Iter [7100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:34:02, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2294, loss_gan_d_photo: 0.2233, loss_gan_g_mask: 0.4061, loss_gan_g_photo: 0.4312, cycle_loss: 3.9918, loss: 4.8291
# 2022-07-25 08:59:50,344 - mmgen - INFO - Iter [7200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:33:34, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2245, loss_gan_d_photo: 0.2231, loss_gan_g_mask: 0.3995, loss_gan_g_photo: 0.4198, cycle_loss: 4.1156, loss: 4.9349
# 2022-07-25 09:00:17,841 - mmgen - INFO - Iter [7300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:33:07, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2358, loss_gan_d_photo: 0.2483, loss_gan_g_mask: 0.4045, loss_gan_g_photo: 0.4067, cycle_loss: 4.1056, loss: 4.9169
# 2022-07-25 09:00:45,323 - mmgen - INFO - Iter [7400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:32:39, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2286, loss_gan_d_photo: 0.2266, loss_gan_g_mask: 0.4341, loss_gan_g_photo: 0.4165, cycle_loss: 4.0843, loss: 4.9350
# 2022-07-25 09:01:12,853 - mmgen - INFO - Iter [7500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:32:12, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2324, loss_gan_d_photo: 0.2323, loss_gan_g_mask: 0.3983, loss_gan_g_photo: 0.3950, cycle_loss: 3.9356, loss: 4.7288
# 2022-07-25 09:01:40,332 - mmgen - INFO - Iter [7600/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:31:44, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2326, loss_gan_d_photo: 0.2292, loss_gan_g_mask: 0.4101, loss_gan_g_photo: 0.3848, cycle_loss: 3.8522, loss: 4.6471
# 2022-07-25 09:02:07,781 - mmgen - INFO - Iter [7700/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:31:16, time: 0.274, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2319, loss_gan_d_photo: 0.2437, loss_gan_g_mask: 0.3668, loss_gan_g_photo: 0.3951, cycle_loss: 3.9600, loss: 4.7219
# 2022-07-25 09:02:35,186 - mmgen - INFO - Iter [7800/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:30:48, time: 0.274, data_time: 0.003, memory: 2631, loss_gan_d_mask: 0.2249, loss_gan_d_photo: 0.2414, loss_gan_g_mask: 0.3656, loss_gan_g_photo: 0.3751, cycle_loss: 4.0459, loss: 4.7866
# 2022-07-25 09:03:02,701 - mmgen - INFO - Iter [7900/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:30:21, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2356, loss_gan_d_photo: 0.2357, loss_gan_g_mask: 0.4107, loss_gan_g_photo: 0.4010, cycle_loss: 3.9920, loss: 4.8038
# 2022-07-25 09:03:30,219 - mmgen - INFO - Iter [8000/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:29:53, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2282, loss_gan_d_photo: 0.2468, loss_gan_g_mask: 0.3840, loss_gan_g_photo: 0.3410, cycle_loss: 3.8324, loss: 4.5574
# 2022-07-25 09:03:57,734 - mmgen - INFO - Iter [8100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:29:26, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2031, loss_gan_d_photo: 0.2078, loss_gan_g_mask: 0.3828, loss_gan_g_photo: 0.3927, cycle_loss: 3.9208, loss: 4.6963
# 2022-07-25 09:04:25,272 - mmgen - INFO - Iter [8200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:28:59, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2490, loss_gan_d_photo: 0.2467, loss_gan_g_mask: 0.4151, loss_gan_g_photo: 0.3892, cycle_loss: 4.0463, loss: 4.8506
# 2022-07-25 09:04:52,793 - mmgen - INFO - Iter [8300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:28:32, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2081, loss_gan_d_photo: 0.2332, loss_gan_g_mask: 0.4151, loss_gan_g_photo: 0.3883, cycle_loss: 3.8524, loss: 4.6558
# 2022-07-25 09:05:20,287 - mmgen - INFO - Iter [8400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:28:04, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2302, loss_gan_d_photo: 0.2239, loss_gan_g_mask: 0.4335, loss_gan_g_photo: 0.4035, cycle_loss: 4.0174, loss: 4.8544
# 2022-07-25 09:05:47,858 - mmgen - INFO - Iter [8500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:27:38, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2193, loss_gan_d_photo: 0.2349, loss_gan_g_mask: 0.4020, loss_gan_g_photo: 0.4026, cycle_loss: 3.9600, loss: 4.7646
# 2022-07-25 09:06:15,374 - mmgen - INFO - Iter [8600/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:27:10, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2362, loss_gan_d_photo: 0.2274, loss_gan_g_mask: 0.3930, loss_gan_g_photo: 0.3964, cycle_loss: 3.8796, loss: 4.6690
# 2022-07-25 09:06:42,771 - mmgen - INFO - Iter [8700/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:26:42, time: 0.274, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2051, loss_gan_d_photo: 0.2401, loss_gan_g_mask: 0.4163, loss_gan_g_photo: 0.3878, cycle_loss: 4.0132, loss: 4.8173
# 2022-07-25 09:07:10,295 - mmgen - INFO - Iter [8800/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:26:15, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2273, loss_gan_d_photo: 0.2334, loss_gan_g_mask: 0.4206, loss_gan_g_photo: 0.3741, cycle_loss: 3.8231, loss: 4.6178
# 2022-07-25 09:07:37,788 - mmgen - INFO - Iter [8900/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:25:47, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2329, loss_gan_d_photo: 0.2283, loss_gan_g_mask: 0.4006, loss_gan_g_photo: 0.3620, cycle_loss: 3.8856, loss: 4.6482
# 2022-07-25 09:08:05,303 - mmgen - INFO - Iter [9000/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:25:20, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2135, loss_gan_d_photo: 0.2451, loss_gan_g_mask: 0.3888, loss_gan_g_photo: 0.4224, cycle_loss: 3.8336, loss: 4.6448
# 2022-07-25 09:08:32,747 - mmgen - INFO - Iter [9100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:24:52, time: 0.274, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2176, loss_gan_d_photo: 0.2398, loss_gan_g_mask: 0.3938, loss_gan_g_photo: 0.4279, cycle_loss: 3.9884, loss: 4.8100
# 2022-07-25 09:09:00,304 - mmgen - INFO - Iter [9200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:24:25, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2170, loss_gan_d_photo: 0.2473, loss_gan_g_mask: 0.3899, loss_gan_g_photo: 0.4079, cycle_loss: 3.7133, loss: 4.5111
# 2022-07-25 09:09:27,814 - mmgen - INFO - Iter [9300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:23:58, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2119, loss_gan_d_photo: 0.2269, loss_gan_g_mask: 0.4517, loss_gan_g_photo: 0.3934, cycle_loss: 3.8432, loss: 4.6883
# 2022-07-25 09:09:55,324 - mmgen - INFO - Iter [9400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:23:30, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2206, loss_gan_d_photo: 0.2380, loss_gan_g_mask: 0.4026, loss_gan_g_photo: 0.4181, cycle_loss: 3.8227, loss: 4.6434
# 2022-07-25 09:10:22,835 - mmgen - INFO - Iter [9500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:23:03, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2509, loss_gan_d_photo: 0.2343, loss_gan_g_mask: 0.3941, loss_gan_g_photo: 0.3697, cycle_loss: 3.6602, loss: 4.4240
# 2022-07-25 09:10:50,282 - mmgen - INFO - Iter [9600/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:22:35, time: 0.274, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2157, loss_gan_d_photo: 0.2169, loss_gan_g_mask: 0.4111, loss_gan_g_photo: 0.4172, cycle_loss: 3.7127, loss: 4.5410
# 2022-07-25 09:11:17,809 - mmgen - INFO - Iter [9700/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:22:08, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2277, loss_gan_d_photo: 0.2417, loss_gan_g_mask: 0.4190, loss_gan_g_photo: 0.4039, cycle_loss: 3.6185, loss: 4.4413
# 2022-07-25 09:11:45,328 - mmgen - INFO - Iter [9800/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:21:40, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1987, loss_gan_d_photo: 0.2233, loss_gan_g_mask: 0.4654, loss_gan_g_photo: 0.4572, cycle_loss: 3.8629, loss: 4.7855
# 2022-07-25 09:12:12,870 - mmgen - INFO - Iter [9900/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:21:13, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2362, loss_gan_d_photo: 0.2483, loss_gan_g_mask: 0.3653, loss_gan_g_photo: 0.4097, cycle_loss: 3.5630, loss: 4.3380
# 2022-07-25 09:12:40,360 - mmgen - INFO - Saving checkpoint at 10000 iterations
# 2022-07-25 09:12:42,497 - mmgen - INFO - Iter [10000/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:21:01, time: 0.296, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1972, loss_gan_d_photo: 0.2136, loss_gan_g_mask: 0.4223, loss_gan_g_photo: 0.4706, cycle_loss: 3.9672, loss: 4.8600
# 2022-07-25 09:13:10,053 - mmgen - INFO - Iter [10100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:20:33, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2183, loss_gan_d_photo: 0.2383, loss_gan_g_mask: 0.3882, loss_gan_g_photo: 0.3705, cycle_loss: 3.5030, loss: 4.2617
# 2022-07-25 09:13:37,693 - mmgen - INFO - Iter [10200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:20:07, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2117, loss_gan_d_photo: 0.2390, loss_gan_g_mask: 0.4043, loss_gan_g_photo: 0.4186, cycle_loss: 3.6646, loss: 4.4875
# 2022-07-25 09:14:05,341 - mmgen - INFO - Iter [10300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:19:40, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2347, loss_gan_d_photo: 0.2480, loss_gan_g_mask: 0.4310, loss_gan_g_photo: 0.3734, cycle_loss: 3.8264, loss: 4.6308
# 2022-07-25 09:14:32,918 - mmgen - INFO - Iter [10400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:19:13, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2123, loss_gan_d_photo: 0.2256, loss_gan_g_mask: 0.4037, loss_gan_g_photo: 0.3630, cycle_loss: 3.8856, loss: 4.6523
# 2022-07-25 09:15:00,578 - mmgen - INFO - Iter [10500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:18:46, time: 0.277, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2104, loss_gan_d_photo: 0.2303, loss_gan_g_mask: 0.3829, loss_gan_g_photo: 0.3908, cycle_loss: 3.7263, loss: 4.5000
# 2022-07-25 09:15:28,223 - mmgen - INFO - Iter [10600/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:18:20, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2344, loss_gan_d_photo: 0.2379, loss_gan_g_mask: 0.4035, loss_gan_g_photo: 0.3581, cycle_loss: 3.6318, loss: 4.3934
# 2022-07-25 09:15:55,887 - mmgen - INFO - Iter [10700/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:17:53, time: 0.277, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2150, loss_gan_d_photo: 0.2303, loss_gan_g_mask: 0.3856, loss_gan_g_photo: 0.3952, cycle_loss: 3.4971, loss: 4.2778
# 2022-07-25 09:16:23,527 - mmgen - INFO - Iter [10800/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:17:26, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2447, loss_gan_d_photo: 0.2334, loss_gan_g_mask: 0.4036, loss_gan_g_photo: 0.4059, cycle_loss: 3.7487, loss: 4.5582
# 2022-07-25 09:16:51,165 - mmgen - INFO - Iter [10900/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:17:00, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2224, loss_gan_d_photo: 0.2336, loss_gan_g_mask: 0.3704, loss_gan_g_photo: 0.3894, cycle_loss: 3.8226, loss: 4.5824
# 2022-07-25 09:17:18,838 - mmgen - INFO - Iter [11000/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:16:33, time: 0.277, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2096, loss_gan_d_photo: 0.2298, loss_gan_g_mask: 0.4152, loss_gan_g_photo: 0.3853, cycle_loss: 3.7461, loss: 4.5466
# 2022-07-25 09:17:46,516 - mmgen - INFO - Iter [11100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:16:06, time: 0.277, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2112, loss_gan_d_photo: 0.2354, loss_gan_g_mask: 0.3747, loss_gan_g_photo: 0.3814, cycle_loss: 3.6719, loss: 4.4279
# 2022-07-25 09:18:14,257 - mmgen - INFO - Iter [11200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:15:40, time: 0.277, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2106, loss_gan_d_photo: 0.2411, loss_gan_g_mask: 0.4175, loss_gan_g_photo: 0.4297, cycle_loss: 3.4563, loss: 4.3035
# 2022-07-25 09:18:41,941 - mmgen - INFO - Iter [11300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:15:13, time: 0.277, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2335, loss_gan_d_photo: 0.2280, loss_gan_g_mask: 0.4007, loss_gan_g_photo: 0.4039, cycle_loss: 3.6274, loss: 4.4320
# 2022-07-25 09:19:09,625 - mmgen - INFO - Iter [11400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:14:47, time: 0.277, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1988, loss_gan_d_photo: 0.2438, loss_gan_g_mask: 0.4149, loss_gan_g_photo: 0.4044, cycle_loss: 3.8470, loss: 4.6663
# 2022-07-25 09:19:37,293 - mmgen - INFO - Iter [11500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:14:20, time: 0.277, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2107, loss_gan_d_photo: 0.2343, loss_gan_g_mask: 0.4311, loss_gan_g_photo: 0.3506, cycle_loss: 3.6202, loss: 4.4019
# 2022-07-25 09:20:04,956 - mmgen - INFO - Iter [11600/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:13:53, time: 0.277, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2163, loss_gan_d_photo: 0.2272, loss_gan_g_mask: 0.4132, loss_gan_g_photo: 0.3658, cycle_loss: 3.6279, loss: 4.4069
# 2022-07-25 09:20:32,597 - mmgen - INFO - Iter [11700/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:13:26, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2014, loss_gan_d_photo: 0.2244, loss_gan_g_mask: 0.4438, loss_gan_g_photo: 0.4278, cycle_loss: 3.6430, loss: 4.5146
# 2022-07-25 09:21:00,222 - mmgen - INFO - Iter [11800/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:12:59, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2149, loss_gan_d_photo: 0.2219, loss_gan_g_mask: 0.4355, loss_gan_g_photo: 0.4178, cycle_loss: 3.5876, loss: 4.4409
# 2022-07-25 09:21:27,891 - mmgen - INFO - Iter [11900/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:12:33, time: 0.277, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2029, loss_gan_d_photo: 0.2382, loss_gan_g_mask: 0.4511, loss_gan_g_photo: 0.4091, cycle_loss: 3.5134, loss: 4.3736
# 2022-07-25 09:21:55,552 - mmgen - INFO - Iter [12000/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:12:06, time: 0.277, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2083, loss_gan_d_photo: 0.2087, loss_gan_g_mask: 0.4523, loss_gan_g_photo: 0.4387, cycle_loss: 3.6650, loss: 4.5560
# 2022-07-25 09:22:23,169 - mmgen - INFO - Iter [12100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:11:39, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2092, loss_gan_d_photo: 0.2429, loss_gan_g_mask: 0.4368, loss_gan_g_photo: 0.3790, cycle_loss: 3.5692, loss: 4.3850
# 2022-07-25 09:22:50,814 - mmgen - INFO - Iter [12200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:11:12, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1999, loss_gan_d_photo: 0.2421, loss_gan_g_mask: 0.4514, loss_gan_g_photo: 0.3690, cycle_loss: 3.5555, loss: 4.3759
# 2022-07-25 09:23:18,468 - mmgen - INFO - Iter [12300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:10:45, time: 0.277, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1998, loss_gan_d_photo: 0.2397, loss_gan_g_mask: 0.4259, loss_gan_g_photo: 0.3818, cycle_loss: 3.6502, loss: 4.4579
# 2022-07-25 09:23:46,146 - mmgen - INFO - Iter [12400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:10:18, time: 0.277, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2105, loss_gan_d_photo: 0.2234, loss_gan_g_mask: 0.4381, loss_gan_g_photo: 0.4097, cycle_loss: 3.6825, loss: 4.5304
# 2022-07-25 09:24:13,812 - mmgen - INFO - Iter [12500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:09:51, time: 0.277, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1905, loss_gan_d_photo: 0.2322, loss_gan_g_mask: 0.4435, loss_gan_g_photo: 0.4041, cycle_loss: 3.8197, loss: 4.6673
# 2022-07-25 09:24:41,512 - mmgen - INFO - Iter [12600/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:09:24, time: 0.277, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2185, loss_gan_d_photo: 0.2181, loss_gan_g_mask: 0.4544, loss_gan_g_photo: 0.4063, cycle_loss: 3.5255, loss: 4.3862
# 2022-07-25 09:25:09,170 - mmgen - INFO - Iter [12700/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:08:57, time: 0.277, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2077, loss_gan_d_photo: 0.2342, loss_gan_g_mask: 0.4071, loss_gan_g_photo: 0.4008, cycle_loss: 3.3914, loss: 4.1993
# 2022-07-25 09:25:36,810 - mmgen - INFO - Iter [12800/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:08:30, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2008, loss_gan_d_photo: 0.2455, loss_gan_g_mask: 0.4136, loss_gan_g_photo: 0.3935, cycle_loss: 3.4972, loss: 4.3044
# 2022-07-25 09:26:04,499 - mmgen - INFO - Iter [12900/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:08:04, time: 0.277, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2179, loss_gan_d_photo: 0.2540, loss_gan_g_mask: 0.4218, loss_gan_g_photo: 0.3462, cycle_loss: 3.2185, loss: 3.9865
# 2022-07-25 09:26:32,122 - mmgen - INFO - Iter [13000/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:07:36, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2002, loss_gan_d_photo: 0.2262, loss_gan_g_mask: 0.4106, loss_gan_g_photo: 0.3827, cycle_loss: 3.2991, loss: 4.0923
# 2022-07-25 09:26:59,744 - mmgen - INFO - Iter [13100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:07:09, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2169, loss_gan_d_photo: 0.2208, loss_gan_g_mask: 0.4079, loss_gan_g_photo: 0.3835, cycle_loss: 3.4562, loss: 4.2477
# 2022-07-25 09:27:27,340 - mmgen - INFO - Iter [13200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:06:42, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2010, loss_gan_d_photo: 0.2134, loss_gan_g_mask: 0.4259, loss_gan_g_photo: 0.4146, cycle_loss: 3.6639, loss: 4.5045
# 2022-07-25 09:27:54,981 - mmgen - INFO - Iter [13300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:06:15, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1970, loss_gan_d_photo: 0.2099, loss_gan_g_mask: 0.4457, loss_gan_g_photo: 0.4448, cycle_loss: 3.6754, loss: 4.5659
# 2022-07-25 09:28:22,640 - mmgen - INFO - Iter [13400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:05:48, time: 0.277, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2102, loss_gan_d_photo: 0.2263, loss_gan_g_mask: 0.4439, loss_gan_g_photo: 0.4130, cycle_loss: 3.6490, loss: 4.5059
# 2022-07-25 09:28:50,309 - mmgen - INFO - Iter [13500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:05:21, time: 0.277, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2148, loss_gan_d_photo: 0.2320, loss_gan_g_mask: 0.4299, loss_gan_g_photo: 0.4097, cycle_loss: 3.4806, loss: 4.3203
# 2022-07-25 09:29:17,952 - mmgen - INFO - Iter [13600/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:04:54, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2033, loss_gan_d_photo: 0.2314, loss_gan_g_mask: 0.4001, loss_gan_g_photo: 0.3746, cycle_loss: 3.4942, loss: 4.2690
# 2022-07-25 09:29:45,585 - mmgen - INFO - Iter [13700/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:04:27, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2166, loss_gan_d_photo: 0.2144, loss_gan_g_mask: 0.4344, loss_gan_g_photo: 0.4179, cycle_loss: 3.4587, loss: 4.3110
# 2022-07-25 09:30:13,232 - mmgen - INFO - Iter [13800/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:04:00, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1973, loss_gan_d_photo: 0.2286, loss_gan_g_mask: 0.3985, loss_gan_g_photo: 0.4425, cycle_loss: 3.3157, loss: 4.1567
# 2022-07-25 09:30:40,826 - mmgen - INFO - Iter [13900/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:03:32, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2157, loss_gan_d_photo: 0.2221, loss_gan_g_mask: 0.4349, loss_gan_g_photo: 0.4068, cycle_loss: 3.5751, loss: 4.4168
# 2022-07-25 09:31:10,863 - mmgen - INFO - Iter [14000/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:03:16, time: 0.300, data_time: 0.027, memory: 2631, loss_gan_d_mask: 0.1915, loss_gan_d_photo: 0.2327, loss_gan_g_mask: 0.4173, loss_gan_g_photo: 0.3923, cycle_loss: 3.5933, loss: 4.4028
# 2022-07-25 09:31:38,505 - mmgen - INFO - Iter [14100/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:02:49, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2094, loss_gan_d_photo: 0.1975, loss_gan_g_mask: 0.5108, loss_gan_g_photo: 0.4549, cycle_loss: 3.3221, loss: 4.2878
# 2022-07-25 09:32:06,141 - mmgen - INFO - Iter [14200/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:02:22, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2200, loss_gan_d_photo: 0.2356, loss_gan_g_mask: 0.4009, loss_gan_g_photo: 0.3985, cycle_loss: 3.6511, loss: 4.4505
# 2022-07-25 09:32:33,784 - mmgen - INFO - Iter [14300/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:01:55, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1945, loss_gan_d_photo: 0.2176, loss_gan_g_mask: 0.4359, loss_gan_g_photo: 0.4057, cycle_loss: 3.5314, loss: 4.3731
# 2022-07-25 09:33:01,395 - mmgen - INFO - Iter [14400/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:01:27, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2157, loss_gan_d_photo: 0.2383, loss_gan_g_mask: 0.4171, loss_gan_g_photo: 0.4264, cycle_loss: 3.5422, loss: 4.3858
# 2022-07-25 09:33:29,027 - mmgen - INFO - Iter [14500/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:01:00, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2148, loss_gan_d_photo: 0.2074, loss_gan_g_mask: 0.4213, loss_gan_g_photo: 0.4238, cycle_loss: 3.5221, loss: 4.3671
# 2022-07-25 09:33:56,636 - mmgen - INFO - Iter [14600/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:00:32, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.2152, loss_gan_d_photo: 0.2242, loss_gan_g_mask: 0.3804, loss_gan_g_photo: 0.3953, cycle_loss: 3.3216, loss: 4.0973
# 2022-07-25 09:34:24,323 - mmgen - INFO - Iter [14700/80000]	lr_generators: 2.000e-04 lr_discriminators: 2.000e-04, eta: 5:00:05, time: 0.277, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1950, loss_gan_d_photo: 0.2258, loss_gan_g_mask: 0.4644, loss_gan_g_photo: 0.4201, cycle_loss: 3.7526, loss: 4.6371
# ...
# 2022-07-25 14:11:39,642 - mmgen - INFO - Iter [75000/80000]	lr_generators: 2.600e-05 lr_discriminators: 2.600e-05, eta: 0:22:59, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1147, loss_gan_d_photo: 0.1701, loss_gan_g_mask: 0.5834, loss_gan_g_photo: 0.4186, cycle_loss: 1.8674, loss: 2.8693
# 2022-07-25 14:12:07,237 - mmgen - INFO - Iter [75100/80000]	lr_generators: 2.600e-05 lr_discriminators: 2.600e-05, eta: 0:22:31, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1262, loss_gan_d_photo: 0.1792, loss_gan_g_mask: 0.5494, loss_gan_g_photo: 0.4061, cycle_loss: 1.8747, loss: 2.8302
# 2022-07-25 14:12:34,890 - mmgen - INFO - Iter [75200/80000]	lr_generators: 2.600e-05 lr_discriminators: 2.600e-05, eta: 0:22:04, time: 0.277, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1221, loss_gan_d_photo: 0.1756, loss_gan_g_mask: 0.5635, loss_gan_g_photo: 0.4157, cycle_loss: 1.9238, loss: 2.9029
# 2022-07-25 14:13:02,467 - mmgen - INFO - Iter [75300/80000]	lr_generators: 2.400e-05 lr_discriminators: 2.400e-05, eta: 0:21:36, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1358, loss_gan_d_photo: 0.1818, loss_gan_g_mask: 0.5221, loss_gan_g_photo: 0.4211, cycle_loss: 1.9642, loss: 2.9074
# 2022-07-25 14:13:29,980 - mmgen - INFO - Iter [75400/80000]	lr_generators: 2.400e-05 lr_discriminators: 2.400e-05, eta: 0:21:08, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1340, loss_gan_d_photo: 0.1713, loss_gan_g_mask: 0.5475, loss_gan_g_photo: 0.4242, cycle_loss: 1.8649, loss: 2.8366
# 2022-07-25 14:13:57,568 - mmgen - INFO - Iter [75500/80000]	lr_generators: 2.400e-05 lr_discriminators: 2.400e-05, eta: 0:20:41, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1386, loss_gan_d_photo: 0.1786, loss_gan_g_mask: 0.5403, loss_gan_g_photo: 0.4260, cycle_loss: 1.8837, loss: 2.8500
# 2022-07-25 14:14:25,183 - mmgen - INFO - Iter [75600/80000]	lr_generators: 2.400e-05 lr_discriminators: 2.400e-05, eta: 0:20:13, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1301, loss_gan_d_photo: 0.1867, loss_gan_g_mask: 0.5602, loss_gan_g_photo: 0.4012, cycle_loss: 1.8949, loss: 2.8564
# 2022-07-25 14:14:52,720 - mmgen - INFO - Iter [75700/80000]	lr_generators: 2.200e-05 lr_discriminators: 2.200e-05, eta: 0:19:46, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1229, loss_gan_d_photo: 0.1970, loss_gan_g_mask: 0.5289, loss_gan_g_photo: 0.3900, cycle_loss: 1.8562, loss: 2.7751
# 2022-07-25 14:15:20,288 - mmgen - INFO - Iter [75800/80000]	lr_generators: 2.200e-05 lr_discriminators: 2.200e-05, eta: 0:19:18, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1175, loss_gan_d_photo: 0.1838, loss_gan_g_mask: 0.5621, loss_gan_g_photo: 0.4070, cycle_loss: 1.8038, loss: 2.7729
# 2022-07-25 14:15:47,792 - mmgen - INFO - Iter [75900/80000]	lr_generators: 2.200e-05 lr_discriminators: 2.200e-05, eta: 0:18:50, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1250, loss_gan_d_photo: 0.1765, loss_gan_g_mask: 0.5433, loss_gan_g_photo: 0.4315, cycle_loss: 1.8843, loss: 2.8592
# 2022-07-25 14:16:15,325 - mmgen - INFO - Iter [76000/80000]	lr_generators: 2.200e-05 lr_discriminators: 2.200e-05, eta: 0:18:23, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1377, loss_gan_d_photo: 0.1674, loss_gan_g_mask: 0.5354, loss_gan_g_photo: 0.4541, cycle_loss: 1.8381, loss: 2.8276
# 2022-07-25 14:16:42,852 - mmgen - INFO - Iter [76100/80000]	lr_generators: 2.000e-05 lr_discriminators: 2.000e-05, eta: 0:17:55, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1261, loss_gan_d_photo: 0.1653, loss_gan_g_mask: 0.5466, loss_gan_g_photo: 0.4439, cycle_loss: 1.8780, loss: 2.8685
# 2022-07-25 14:17:10,403 - mmgen - INFO - Iter [76200/80000]	lr_generators: 2.000e-05 lr_discriminators: 2.000e-05, eta: 0:17:28, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1212, loss_gan_d_photo: 0.1765, loss_gan_g_mask: 0.5580, loss_gan_g_photo: 0.4129, cycle_loss: 1.9633, loss: 2.9341
# 2022-07-25 14:17:37,885 - mmgen - INFO - Iter [76300/80000]	lr_generators: 2.000e-05 lr_discriminators: 2.000e-05, eta: 0:17:00, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1253, loss_gan_d_photo: 0.1836, loss_gan_g_mask: 0.5553, loss_gan_g_photo: 0.3675, cycle_loss: 1.8694, loss: 2.7922
# 2022-07-25 14:18:05,427 - mmgen - INFO - Iter [76400/80000]	lr_generators: 2.000e-05 lr_discriminators: 2.000e-05, eta: 0:16:33, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1371, loss_gan_d_photo: 0.1813, loss_gan_g_mask: 0.5602, loss_gan_g_photo: 0.4054, cycle_loss: 1.7839, loss: 2.7495
# 2022-07-25 14:18:32,941 - mmgen - INFO - Iter [76500/80000]	lr_generators: 1.800e-05 lr_discriminators: 1.800e-05, eta: 0:16:05, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1145, loss_gan_d_photo: 0.1785, loss_gan_g_mask: 0.5567, loss_gan_g_photo: 0.4229, cycle_loss: 1.8784, loss: 2.8579
# 2022-07-25 14:19:00,418 - mmgen - INFO - Iter [76600/80000]	lr_generators: 1.800e-05 lr_discriminators: 1.800e-05, eta: 0:15:37, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1208, loss_gan_d_photo: 0.1712, loss_gan_g_mask: 0.5671, loss_gan_g_photo: 0.4029, cycle_loss: 1.8563, loss: 2.8263
# 2022-07-25 14:19:27,888 - mmgen - INFO - Iter [76700/80000]	lr_generators: 1.800e-05 lr_discriminators: 1.800e-05, eta: 0:15:10, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1223, loss_gan_d_photo: 0.1666, loss_gan_g_mask: 0.5812, loss_gan_g_photo: 0.4503, cycle_loss: 1.8557, loss: 2.8873
# 2022-07-25 14:19:57,796 - mmgen - INFO - Iter [76800/80000]	lr_generators: 1.800e-05 lr_discriminators: 1.800e-05, eta: 0:14:42, time: 0.299, data_time: 0.027, memory: 2631, loss_gan_d_mask: 0.1160, loss_gan_d_photo: 0.1811, loss_gan_g_mask: 0.5840, loss_gan_g_photo: 0.4024, cycle_loss: 1.9853, loss: 2.9717
# 2022-07-25 14:20:25,346 - mmgen - INFO - Iter [76900/80000]	lr_generators: 1.600e-05 lr_discriminators: 1.600e-05, eta: 0:14:15, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1214, loss_gan_d_photo: 0.1645, loss_gan_g_mask: 0.5762, loss_gan_g_photo: 0.4415, cycle_loss: 1.8835, loss: 2.9012
# 2022-07-25 14:20:52,889 - mmgen - INFO - Iter [77000/80000]	lr_generators: 1.600e-05 lr_discriminators: 1.600e-05, eta: 0:13:47, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1252, loss_gan_d_photo: 0.1772, loss_gan_g_mask: 0.5710, loss_gan_g_photo: 0.4074, cycle_loss: 1.7950, loss: 2.7735
# 2022-07-25 14:21:20,392 - mmgen - INFO - Iter [77100/80000]	lr_generators: 1.600e-05 lr_discriminators: 1.600e-05, eta: 0:13:20, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1160, loss_gan_d_photo: 0.1682, loss_gan_g_mask: 0.5670, loss_gan_g_photo: 0.4330, cycle_loss: 1.9167, loss: 2.9167
# 2022-07-25 14:21:47,831 - mmgen - INFO - Iter [77200/80000]	lr_generators: 1.600e-05 lr_discriminators: 1.600e-05, eta: 0:12:52, time: 0.274, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1193, loss_gan_d_photo: 0.1637, loss_gan_g_mask: 0.5471, loss_gan_g_photo: 0.4489, cycle_loss: 1.8474, loss: 2.8434
# 2022-07-25 14:22:15,343 - mmgen - INFO - Iter [77300/80000]	lr_generators: 1.400e-05 lr_discriminators: 1.400e-05, eta: 0:12:24, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1223, loss_gan_d_photo: 0.1723, loss_gan_g_mask: 0.5470, loss_gan_g_photo: 0.4340, cycle_loss: 1.8462, loss: 2.8272
# 2022-07-25 14:22:42,903 - mmgen - INFO - Iter [77400/80000]	lr_generators: 1.400e-05 lr_discriminators: 1.400e-05, eta: 0:11:57, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1297, loss_gan_d_photo: 0.1710, loss_gan_g_mask: 0.6006, loss_gan_g_photo: 0.4317, cycle_loss: 1.8439, loss: 2.8761
# 2022-07-25 14:23:10,408 - mmgen - INFO - Iter [77500/80000]	lr_generators: 1.400e-05 lr_discriminators: 1.400e-05, eta: 0:11:29, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1265, loss_gan_d_photo: 0.1618, loss_gan_g_mask: 0.5895, loss_gan_g_photo: 0.4457, cycle_loss: 1.8587, loss: 2.8938
# 2022-07-25 14:23:37,926 - mmgen - INFO - Iter [77600/80000]	lr_generators: 1.400e-05 lr_discriminators: 1.400e-05, eta: 0:11:02, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1252, loss_gan_d_photo: 0.1848, loss_gan_g_mask: 0.5497, loss_gan_g_photo: 0.4221, cycle_loss: 1.8444, loss: 2.8163
# 2022-07-25 14:24:05,389 - mmgen - INFO - Iter [77700/80000]	lr_generators: 1.200e-05 lr_discriminators: 1.200e-05, eta: 0:10:34, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1206, loss_gan_d_photo: 0.1679, loss_gan_g_mask: 0.5623, loss_gan_g_photo: 0.4319, cycle_loss: 1.8972, loss: 2.8914
# 2022-07-25 14:24:32,831 - mmgen - INFO - Iter [77800/80000]	lr_generators: 1.200e-05 lr_discriminators: 1.200e-05, eta: 0:10:06, time: 0.274, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1262, loss_gan_d_photo: 0.1756, loss_gan_g_mask: 0.5334, loss_gan_g_photo: 0.4193, cycle_loss: 1.8791, loss: 2.8318
# 2022-07-25 14:25:00,298 - mmgen - INFO - Iter [77900/80000]	lr_generators: 1.200e-05 lr_discriminators: 1.200e-05, eta: 0:09:39, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1283, loss_gan_d_photo: 0.1676, loss_gan_g_mask: 0.6047, loss_gan_g_photo: 0.4312, cycle_loss: 1.8245, loss: 2.8604
# 2022-07-25 14:25:27,711 - mmgen - INFO - Iter [78000/80000]	lr_generators: 1.200e-05 lr_discriminators: 1.200e-05, eta: 0:09:11, time: 0.274, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1176, loss_gan_d_photo: 0.1683, loss_gan_g_mask: 0.5905, loss_gan_g_photo: 0.4357, cycle_loss: 1.7668, loss: 2.7929
# 2022-07-25 14:25:55,201 - mmgen - INFO - Iter [78100/80000]	lr_generators: 1.000e-05 lr_discriminators: 1.000e-05, eta: 0:08:44, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1212, loss_gan_d_photo: 0.1744, loss_gan_g_mask: 0.5583, loss_gan_g_photo: 0.4048, cycle_loss: 1.8550, loss: 2.8182
# 2022-07-25 14:26:22,711 - mmgen - INFO - Iter [78200/80000]	lr_generators: 1.000e-05 lr_discriminators: 1.000e-05, eta: 0:08:16, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1149, loss_gan_d_photo: 0.1791, loss_gan_g_mask: 0.6016, loss_gan_g_photo: 0.4345, cycle_loss: 1.8939, loss: 2.9300
# 2022-07-25 14:26:50,144 - mmgen - INFO - Iter [78300/80000]	lr_generators: 1.000e-05 lr_discriminators: 1.000e-05, eta: 0:07:48, time: 0.274, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1249, loss_gan_d_photo: 0.1666, loss_gan_g_mask: 0.5409, loss_gan_g_photo: 0.4430, cycle_loss: 1.9227, loss: 2.9066
# 2022-07-25 14:27:17,562 - mmgen - INFO - Iter [78400/80000]	lr_generators: 1.000e-05 lr_discriminators: 1.000e-05, eta: 0:07:21, time: 0.274, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1251, loss_gan_d_photo: 0.1550, loss_gan_g_mask: 0.5708, loss_gan_g_photo: 0.4292, cycle_loss: 1.8466, loss: 2.8466
# 2022-07-25 14:27:45,056 - mmgen - INFO - Iter [78500/80000]	lr_generators: 8.000e-06 lr_discriminators: 8.000e-06, eta: 0:06:53, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1308, loss_gan_d_photo: 0.1725, loss_gan_g_mask: 0.5817, loss_gan_g_photo: 0.4000, cycle_loss: 1.8509, loss: 2.8326
# 2022-07-25 14:28:12,609 - mmgen - INFO - Iter [78600/80000]	lr_generators: 8.000e-06 lr_discriminators: 8.000e-06, eta: 0:06:26, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1157, loss_gan_d_photo: 0.1804, loss_gan_g_mask: 0.5731, loss_gan_g_photo: 0.4109, cycle_loss: 1.8277, loss: 2.8117
# 2022-07-25 14:28:40,123 - mmgen - INFO - Iter [78700/80000]	lr_generators: 8.000e-06 lr_discriminators: 8.000e-06, eta: 0:05:58, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1235, loss_gan_d_photo: 0.1899, loss_gan_g_mask: 0.5644, loss_gan_g_photo: 0.4280, cycle_loss: 1.8201, loss: 2.8126
# 2022-07-25 14:29:07,637 - mmgen - INFO - Iter [78800/80000]	lr_generators: 8.000e-06 lr_discriminators: 8.000e-06, eta: 0:05:31, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1192, loss_gan_d_photo: 0.1740, loss_gan_g_mask: 0.5710, loss_gan_g_photo: 0.4228, cycle_loss: 1.8107, loss: 2.8044
# 2022-07-25 14:29:35,131 - mmgen - INFO - Iter [78900/80000]	lr_generators: 6.000e-06 lr_discriminators: 6.000e-06, eta: 0:05:03, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1152, loss_gan_d_photo: 0.1756, loss_gan_g_mask: 0.5864, loss_gan_g_photo: 0.4184, cycle_loss: 1.8127, loss: 2.8175
# 2022-07-25 14:30:02,648 - mmgen - INFO - Iter [79000/80000]	lr_generators: 6.000e-06 lr_discriminators: 6.000e-06, eta: 0:04:35, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1180, loss_gan_d_photo: 0.1669, loss_gan_g_mask: 0.5925, loss_gan_g_photo: 0.4192, cycle_loss: 1.8632, loss: 2.8750
# 2022-07-25 14:30:30,125 - mmgen - INFO - Iter [79100/80000]	lr_generators: 6.000e-06 lr_discriminators: 6.000e-06, eta: 0:04:08, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1172, loss_gan_d_photo: 0.1678, loss_gan_g_mask: 0.5789, loss_gan_g_photo: 0.4376, cycle_loss: 1.7768, loss: 2.7933
# 2022-07-25 14:30:57,606 - mmgen - INFO - Iter [79200/80000]	lr_generators: 6.000e-06 lr_discriminators: 6.000e-06, eta: 0:03:40, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1181, loss_gan_d_photo: 0.1615, loss_gan_g_mask: 0.5990, loss_gan_g_photo: 0.4730, cycle_loss: 1.8636, loss: 2.9355
# 2022-07-25 14:31:25,169 - mmgen - INFO - Iter [79300/80000]	lr_generators: 4.000e-06 lr_discriminators: 4.000e-06, eta: 0:03:13, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1147, loss_gan_d_photo: 0.1695, loss_gan_g_mask: 0.5764, loss_gan_g_photo: 0.4499, cycle_loss: 1.8117, loss: 2.8380
# 2022-07-25 14:31:52,724 - mmgen - INFO - Iter [79400/80000]	lr_generators: 4.000e-06 lr_discriminators: 4.000e-06, eta: 0:02:45, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1281, loss_gan_d_photo: 0.1776, loss_gan_g_mask: 0.5453, loss_gan_g_photo: 0.4042, cycle_loss: 1.8185, loss: 2.7680
# 2022-07-25 14:32:20,301 - mmgen - INFO - Iter [79500/80000]	lr_generators: 4.000e-06 lr_discriminators: 4.000e-06, eta: 0:02:17, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1101, loss_gan_d_photo: 0.1619, loss_gan_g_mask: 0.6073, loss_gan_g_photo: 0.4490, cycle_loss: 1.8383, loss: 2.8946
# 2022-07-25 14:32:47,880 - mmgen - INFO - Iter [79600/80000]	lr_generators: 4.000e-06 lr_discriminators: 4.000e-06, eta: 0:01:50, time: 0.276, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1175, loss_gan_d_photo: 0.1722, loss_gan_g_mask: 0.5880, loss_gan_g_photo: 0.4640, cycle_loss: 1.8255, loss: 2.8775
# 2022-07-25 14:33:15,422 - mmgen - INFO - Iter [79700/80000]	lr_generators: 2.000e-06 lr_discriminators: 2.000e-06, eta: 0:01:22, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1168, loss_gan_d_photo: 0.1631, loss_gan_g_mask: 0.6031, loss_gan_g_photo: 0.4158, cycle_loss: 1.8536, loss: 2.8725
# 2022-07-25 14:33:42,921 - mmgen - INFO - Iter [79800/80000]	lr_generators: 2.000e-06 lr_discriminators: 2.000e-06, eta: 0:00:55, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1202, loss_gan_d_photo: 0.1669, loss_gan_g_mask: 0.5824, loss_gan_g_photo: 0.4501, cycle_loss: 1.8293, loss: 2.8618
# 2022-07-25 14:34:10,423 - mmgen - INFO - Iter [79900/80000]	lr_generators: 2.000e-06 lr_discriminators: 2.000e-06, eta: 0:00:27, time: 0.275, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1194, loss_gan_d_photo: 0.1736, loss_gan_g_mask: 0.5777, loss_gan_g_photo: 0.4511, cycle_loss: 1.8253, loss: 2.8540
# 2022-07-25 14:34:37,879 - mmgen - INFO - Saving checkpoint at 80000 iterations
# 2022-07-25 14:34:40,350 - mmgen - INFO - Iter [80000/80000]	lr_generators: 2.000e-06 lr_discriminators: 2.000e-06, eta: 0:00:00, time: 0.299, data_time: 0.004, memory: 2631, loss_gan_d_mask: 0.1201, loss_gan_d_photo: 0.1747, loss_gan_g_mask: 0.5826, loss_gan_g_photo: 0.4245, cycle_loss: 1.8333, loss: 2.8404

# %% [markdown]
# # 学習結果の確認
# MMGenerationの「sample_img2img_model」ではうまく動作しなかったため「sample_img2img_model2」を作成して動作させています。
# おそらくモデルの中にコンフィグを格納できていないことが原因だと思われます。

# %%
cfg2 = cfg

from mmgen.datasets.pipelines import Compose
from mmgen.models import BaseTranslationModel

from mmcv.parallel import collate, scatter
from mmcv.runner import load_checkpoint
from mmcv.utils import is_list_of

def sample_img2img_model2(model, image_path, target_domain=None, **kwargs):
    """Sampling from translation models.

    Args:
        model (nn.Module): The loaded model.
        image_path (str): File path of input image.
        style (str): Target style of output image.
    Returns:
        Tensor: Translated image tensor.
    """
    assert isinstance(model, BaseTranslationModel)

    # get source domain and target domain
    if target_domain is None:
        target_domain = model._default_domain
    source_domain = model.get_other_domains(target_domain)[0]

    #cfg = model._cfg
    cfg = cfg2
    device = next(model.parameters()).device  # model device
    # build the data pipeline
    test_pipeline = Compose(cfg.test_pipeline)

    # prepare data
    data = dict()
    # dirty code to deal with test data pipeline
    data['pair_path'] = image_path
    data[f'img_{source_domain}_path'] = image_path
    data[f'img_{target_domain}_path'] = image_path

    data = test_pipeline(data)
    if device.type == 'cpu':
        data = collate([data], samples_per_gpu=1)
        data['meta'] = []
    else:
        data = scatter(collate([data], samples_per_gpu=1), [device])[0]

    source_image = data[f'img_{source_domain}']
    # forward the model
    with torch.no_grad():
        results = model(
            source_image,
            test_mode=True,
            target_domain=target_domain,
            **kwargs)
    output = results['target']
    return output

# %%
from mmgen.apis import sample_img2img_model

test_folder = "/content/drive/MyDrive/kaggle/monet/testB"

test_images = glob(test_folder + "/*.jpg")

m = len(test_images)

plt.figure(figsize=(24,120))

for i,image_path in enumerate(test_images):
    original_image = cv2.imread(image_path)
    original_image = cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB)
    plt.subplot(m,2,(i * 2) + 1)
    plt.imshow(original_image)

    # データの変換（trainAのmask画像のスタイルに画像を変換します。）
    translated_image = sample_img2img_model2(model, image_path, target_domain='mask')
    translate_image = translated_image.cpu().numpy()[0]
    translate_image = translate_image.transpose(1,2,0)
    plt.subplot(m,2,(i * 2) + 2)
    plt.imshow(translate_image)

plt.show()
